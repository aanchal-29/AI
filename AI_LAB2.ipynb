# %% [markdown]
# <a href="https://colab.research.google.com/github/aanchal-29/AI/blob/main/AI_LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def random_chromosome(size): #making random chromosomes
    return [ random.randint(1, nq) for _ in range(nq) ]

def fitness(chromosome):
    horizontal_collisions = sum([chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = [0] * 2*n
    right_diagonal = [0] * 2*n
    for i in range(n):
        left_diagonal[i + chromosome[i] - 1] += 1
        right_diagonal[len(chromosome) - i + chromosome[i] - 2] += 1

    diagonal_collisions = 0
    for i in range(2*n-1):
        counter = 0
        if left_diagonal[i] > 1:
            counter += left_diagonal[i]-1
        if right_diagonal[i] > 1:
            counter += right_diagonal[i]-1
        diagonal_collisions += counter / (n-abs(i-n+1))

    return int(maxFitness - (horizontal_collisions + diagonal_collisions)) #28-(2+3)=23

def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

def random_pick(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(w for c, w in populationWithProbabilty)
    r = random.uniform(0, total)
    upto = 0
    for c, w in zip(population, probabilities):
        if upto + w >= r:
            return c
        upto += w
    assert False, "Shouldn't get here"

def reproduce(x, y): #doing cross_over between two chromosomes
    n = len(x)
    c = random.randint(0, n - 1)
    return x[0:c] + y[c:n]

def mutate(x):  #randomly changing the value of a random index of a chromosome
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(1, n)
    x[c] = m
    return x

def genetic_queen(population, fitness):
    mutation_probability = 0.03
    new_population = []
    probabilities = [probability(n, fitness) for n in population]
    for i in range(len(population)):
        x = random_pick(population, probabilities) #best chromosome 1
        y = random_pick(population, probabilities) #best chromosome 2
        child = reproduce(x, y) #creating two new chromosomes from the best 2 chromosomes
        if random.random() < mutation_probability:
            child = mutate(child)
        print_chromosome(child)
        new_population.append(child)
        if fitness(child) == maxFitness: break
    return new_population

def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
        .format(str(chrom), fitness(chrom)))

if __name__ == "__main__":
    nq = int(input("Enter Number of Queens: ")) #say N = 8
    maxFitness = (nq*(nq-1))/2  # 8*7/2 = 28
    population = [random_chromosome(nq) for _ in range(100)]

    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print("=== Generation {} ===".format(generation))
        population = genetic_queen(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(max([fitness(n) for n in population])))
        generation += 1
    chrom_out = []
    print("Solved in Generation {}!".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("");
            print("One of the solutions: ")
            chrom_out = chrom
            print_chromosome(chrom)

    board = []

    for x in range(nq):
        board.append(["x"] * nq)

    for i in range(nq):
        board[nq-chrom_out[i]][i]="Q"


    def print_board(board):
        for row in board:
            print (" ".join(row))

    print()
    print_board(board)
# Out:
# Enter Number of Queens: 4
# === Generation 1 ===
# Chromosome = [4, 1, 4, 3],  Fitness = 4
# Chromosome = [4, 3, 1, 3],  Fitness = 4
# Chromosome = [4, 1, 3, 1],  Fitness = 4
# Chromosome = [1, 3, 2, 4],  Fitness = 5
# Chromosome = [4, 3, 3, 1],  Fitness = 4
# Chromosome = [1, 1, 2, 2],  Fitness = 3
# Chromosome = [2, 1, 3, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [1, 2, 1, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 1],  Fitness = 4
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 2, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [1, 2, 2, 1],  Fitness = 3
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 1, 4, 1],  Fitness = 5
# Chromosome = [2, 2, 4, 3],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 4, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [4, 3, 1, 3],  Fitness = 4
# Chromosome = [2, 3, 3, 3],  Fitness = 2
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [1, 3, 4, 3],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 4, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 3, 3, 2],  Fitness = 4
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [3, 4, 3, 2],  Fitness = 3
# Chromosome = [3, 1, 1, 4],  Fitness = 4
# Chromosome = [1, 4, 4, 4],  Fitness = 2
# Chromosome = [3, 4, 4, 2],  Fitness = 4
# Chromosome = [2, 4, 3, 2],  Fitness = 4
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [4, 3, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 1, 3, 3],  Fitness = 3
# Chromosome = [3, 4, 3, 2],  Fitness = 3
# Chromosome = [1, 1, 1, 3],  Fitness = 2
# Chromosome = [1, 3, 1, 3],  Fitness = 4
# Chromosome = [1, 3, 1, 4],  Fitness = 4
# Chromosome = [3, 1, 2, 2],  Fitness = 4
# Chromosome = [2, 2, 1, 3],  Fitness = 4
# Chromosome = [1, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 3, 3, 1],  Fitness = 4
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 4, 3, 2],  Fitness = 3
# Chromosome = [2, 2, 4, 1],  Fitness = 4
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [3, 4, 3, 3],  Fitness = 2
# Chromosome = [1, 3, 1, 2],  Fitness = 4
# Chromosome = [2, 2, 4, 1],  Fitness = 4
# Chromosome = [2, 4, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 3, 1],  Fitness = 4
# Chromosome = [1, 4, 2, 3],  Fitness = 5
# Chromosome = [2, 2, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 1, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 4, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [3, 2, 3, 3],  Fitness = 2
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [3, 2, 3, 3],  Fitness = 2
# Chromosome = [1, 3, 1, 3],  Fitness = 4
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [4, 3, 1, 3],  Fitness = 4
# Chromosome = [2, 2, 3, 3],  Fitness = 3
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [4, 3, 3, 1],  Fitness = 4
# Chromosome = [3, 3, 1, 3],  Fitness = 2
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [2, 4, 2, 4],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 1, 4, 1],  Fitness = 4
# Chromosome = [3, 1, 3, 2],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [3, 2, 3, 3],  Fitness = 2
# Chromosome = [2, 3, 3, 3],  Fitness = 2
# Chromosome = [3, 4, 4, 2],  Fitness = 4
# Chromosome = [3, 4, 3, 2],  Fitness = 3
# Chromosome = [2, 3, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 1, 1],  Fitness = 2
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [2, 3, 1, 2],  Fitness = 4
#
# Maximum Fitness = 5
# === Generation 2 ===
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [2, 4, 4, 4],  Fitness = 2
# Chromosome = [2, 2, 4, 1],  Fitness = 4
# Chromosome = [1, 4, 2, 4],  Fitness = 4
# Chromosome = [2, 4, 3, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 1],  Fitness = 4
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [3, 2, 4, 3],  Fitness = 4
# Chromosome = [1, 2, 1, 3],  Fitness = 4
# Chromosome = [2, 3, 3, 3],  Fitness = 2
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [2, 3, 1, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 2],  Fitness = 3
# Chromosome = [4, 1, 3, 3],  Fitness = 4
# Chromosome = [2, 2, 3, 1],  Fitness = 4
# Chromosome = [3, 3, 1, 3],  Fitness = 2
# Chromosome = [1, 3, 3, 3],  Fitness = 2
# Chromosome = [4, 1, 1, 4],  Fitness = 4
# Chromosome = [2, 4, 2, 4],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 1, 1, 4],  Fitness = 4
# Chromosome = [3, 1, 1, 2],  Fitness = 4
# Chromosome = [1, 4, 2, 3],  Fitness = 5
# Chromosome = [2, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [2, 1, 1, 3],  Fitness = 4
# Chromosome = [1, 2, 1, 4],  Fitness = 4
# Chromosome = [3, 1, 2, 2],  Fitness = 4
# Chromosome = [1, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 1, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [1, 1, 3, 1],  Fitness = 2
# Chromosome = [1, 3, 1, 1],  Fitness = 2
# Chromosome = [2, 4, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 3, 3],  Fitness = 2
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [2, 3, 3, 3],  Fitness = 2
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [2, 4, 4, 3],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [1, 2, 1, 2],  Fitness = 2
# Chromosome = [1, 3, 1, 3],  Fitness = 4
# Chromosome = [1, 3, 2, 3],  Fitness = 4
# Chromosome = [3, 4, 4, 2],  Fitness = 4
# Chromosome = [1, 2, 3, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [4, 3, 1, 3],  Fitness = 4
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 3, 1, 3],  Fitness = 4
# Chromosome = [1, 1, 3, 3],  Fitness = 3
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [3, 1, 4, 3],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [2, 4, 2, 3],  Fitness = 4
# Chromosome = [3, 1, 1, 4],  Fitness = 4
# Chromosome = [1, 3, 1, 4],  Fitness = 4
# Chromosome = [2, 4, 4, 1],  Fitness = 4
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 1, 4, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 4, 4, 2],  Fitness = 2
# Chromosome = [2, 3, 1, 3],  Fitness = 4
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [3, 4, 3, 1],  Fitness = 4
# Chromosome = [4, 2, 4, 1],  Fitness = 4
# Chromosome = [1, 4, 2, 3],  Fitness = 5
# Chromosome = [4, 3, 1, 2],  Fitness = 5
# Chromosome = [2, 2, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 2, 3],  Fitness = 3
# Chromosome = [2, 3, 4, 1],  Fitness = 5
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 3, 3, 1],  Fitness = 2
# Chromosome = [3, 1, 4, 3],  Fitness = 4
# Chromosome = [4, 3, 4, 1],  Fitness = 4
# Chromosome = [1, 4, 2, 1],  Fitness = 4
# Chromosome = [1, 2, 3, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 4, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [1, 4, 4, 4],  Fitness = 2
# Chromosome = [2, 2, 1, 1],  Fitness = 3
# Chromosome = [1, 3, 4, 2],  Fitness = 5
# Chromosome = [3, 1, 1, 4],  Fitness = 4
# Chromosome = [3, 2, 2, 1],  Fitness = 4
# Chromosome = [1, 2, 2, 1],  Fitness = 3
# Chromosome = [2, 3, 2, 4],  Fitness = 4
# Chromosome = [2, 4, 1, 1],  Fitness = 5
#
# Maximum Fitness = 5
# === Generation 3 ===
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [1, 4, 4, 3],  Fitness = 4
# Chromosome = [1, 2, 3, 2],  Fitness = 4
# Chromosome = [2, 1, 4, 3],  Fitness = 4
# Chromosome = [4, 3, 1, 2],  Fitness = 5
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 2, 3, 1],  Fitness = 4
# Chromosome = [3, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 4],  Fitness = 5
# Chromosome = [2, 4, 2, 3],  Fitness = 4
# Chromosome = [2, 1, 1, 4],  Fitness = 4
# Chromosome = [1, 4, 2, 4],  Fitness = 4
# Chromosome = [2, 1, 1, 4],  Fitness = 4
# Chromosome = [1, 4, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 4, 4, 2],  Fitness = 4
# Chromosome = [3, 1, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 3, 1, 2],  Fitness = 5
# Chromosome = [3, 4, 1, 2],  Fitness = 4
# Chromosome = [4, 3, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [1, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 2, 2, 1],  Fitness = 4
# Chromosome = [2, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 1, 1, 2],  Fitness = 4
# Chromosome = [3, 4, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 1],  Fitness = 4
# Chromosome = [3, 4, 3, 1],  Fitness = 4
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [1, 2, 3, 1],  Fitness = 4
# Chromosome = [2, 4, 4, 4],  Fitness = 2
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 2, 2, 1],  Fitness = 4
# Chromosome = [3, 2, 3, 3],  Fitness = 2
# Chromosome = [4, 3, 4, 2],  Fitness = 4
# Chromosome = [1, 4, 2, 3],  Fitness = 5
# Chromosome = [2, 3, 4, 1],  Fitness = 5
# Chromosome = [3, 4, 3, 1],  Fitness = 4
# Chromosome = [3, 2, 3, 3],  Fitness = 2
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 4, 4, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 3],  Fitness = 4
# Chromosome = [2, 1, 1, 3],  Fitness = 4
# Chromosome = [2, 4, 2, 4],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [2, 1, 2, 4],  Fitness = 4
# Chromosome = [2, 4, 4, 1],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 4, 4, 3],  Fitness = 3
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 3, 2, 4],  Fitness = 4
# Chromosome = [2, 4, 3, 4],  Fitness = 4
# Chromosome = [3, 4, 3, 3],  Fitness = 2
# Chromosome = [2, 2, 1, 1],  Fitness = 3
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [2, 4, 1, 3],  Fitness = 6
#
# Maximum Fitness = 6
# Solved in Generation 3!
#
# One of the solutions:
# Chromosome = [2, 4, 1, 3],  Fitness = 6
#
# x Q x x
# x x x Q
# Q x x x
# x x Q x

# %%
def printBoard(board):
    print(board[1] + '|' + board[2] + '|' + board[3])
    print('-+-+-')
    print(board[4] + '|' + board[5] + '|' + board[6])
    print('-+-+-')
    print(board[7] + '|' + board[8] + '|' + board[9])
    print("\n")


def spaceIsFree(position):
    if board[position] == ' ':
        return True
    else:
        return False


def insertLetter(letter, position):
    if spaceIsFree(position):
        board[position] = letter
        printBoard(board)
        if (checkDraw()):
            print("Draw!")
            exit()
        if checkForWin():
            if letter == 'X':
                print("Bot wins!")
                exit()
            else:
                print("Player wins!")
                exit()

        return


    else:
        print("Can't insert there!")
        position = int(input("Please enter new position:  "))
        insertLetter(letter, position)
        return


def checkForWin():
    if (board[1] == board[2] and board[1] == board[3] and board[1] != ' '):
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] != ' '):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] != ' '):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] != ' '):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] != ' '):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] != ' '):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] != ' '):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] != ' '):
        return True
    else:
        return False


def checkWhichMarkWon(mark):
    if board[1] == board[2] and board[1] == board[3] and board[1] == mark:
        return True
    elif (board[4] == board[5] and board[4] == board[6] and board[4] == mark):
        return True
    elif (board[7] == board[8] and board[7] == board[9] and board[7] == mark):
        return True
    elif (board[1] == board[4] and board[1] == board[7] and board[1] == mark):
        return True
    elif (board[2] == board[5] and board[2] == board[8] and board[2] == mark):
        return True
    elif (board[3] == board[6] and board[3] == board[9] and board[3] == mark):
        return True
    elif (board[1] == board[5] and board[1] == board[9] and board[1] == mark):
        return True
    elif (board[7] == board[5] and board[7] == board[3] and board[7] == mark):
        return True
    else:
        return False


def checkDraw():
    for key in board.keys():
        if (board[key] == ' '):
            return False
    return True


def playerMove():
    position = int(input("Enter the position for 'O':  "))
    insertLetter(player, position)
    return


def compMove():
    bestScore = -800
    bestMove = 0
    for key in board.keys():
        if (board[key] == ' '):
            board[key] = bot
            score = minimax(board, 0, False)
            board[key] = ' '
            if (score > bestScore):
                bestScore = score
                bestMove = key

    insertLetter(bot, bestMove)
    return


def minimax(board, depth, isMaximizing):

    if (checkWhichMarkWon(bot)):
        return 1
    elif (checkWhichMarkWon(player)):
        return -1
    elif (checkDraw()):
        return 0

    if (isMaximizing):
        bestScore = -800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = bot
                score = minimax(board, depth + 1, False)
                board[key] = ' '
                if (score > bestScore):
                    bestScore = score
        return bestScore

    else:
        bestScore = 800
        for key in board.keys():
            if (board[key] == ' '):
                board[key] = player
                score = minimax(board, depth + 1, True)
                board[key] = ' '
                if (score < bestScore):
                    bestScore = score
        return bestScore



board = {1: ' ', 2: ' ', 3: ' ',
         4: ' ', 5: ' ', 6: ' ',
         7: ' ', 8: ' ', 9: ' '}

printBoard(board)
print("Computer goes first! Good luck.")
print("Positions are as follow:")
print("1, 2, 3 ")
print("4, 5, 6 ")
print("7, 8, 9 ")
print("\n")
player = 'O'
bot = 'X'


global firstComputerMove
firstComputerMove = True

while not checkForWin():
    compMove()
    playerMove()
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
#
#
# Computer goes first! Good luck.
# Positions are as follow:
# 1, 2, 3
# 4, 5, 6
# 7, 8, 9
#
#
# X| |
# -+-+-
#  | |
# -+-+-
#  | |
#
#
# X| |
# -+-+-
#  |O|
# -+-+-
#  | |
#
#
# X|X|
# -+-+-
#  |O|
# -+-+-
#  | |
#
#
# X|X|O
# -+-+-
#  |O|
# -+-+-
#  | |
#
#
# X|X|O
# -+-+-
#  |O|
# -+-+-
# X| |
#
#
# X|X|O
# -+-+-
# O|O|
# -+-+-
# X| |
#
#
# X|X|O
# -+-+-
# O|O|X
# -+-+-
# X| |
#
#
# X|X|O
# -+-+-
# O|O|X
# -+-+-
# X| |O
#
#
# X|X|O
# -+-+-
# O|O|X
# -+-+-
# X|X|O
#
#
# Draw!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d0e008881a15> in <module>
#     164 while not checkForWin():
#     165     compMove()
# --> 166     playerMove()
#
# <ipython-input-2-d0e008881a15> in playerMove()
#      90
#      91 def playerMove():
# ---> 92     position = int(input("Enter the position for 'O':  "))
#      93     insertLetter(player, position)
#      94     return
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import random

def random_chromosome(size): #making random chromosomes
    return [ random.randint(1, nq) for _ in range(nq) ]

def fitness(chromosome):
    horizontal_collisions = sum([chromosome.count(queen)-1 for queen in chromosome])/2
    diagonal_collisions = 0

    n = len(chromosome)
    left_diagonal = [0] * 2*n
    right_diagonal = [0] * 2*n
    for i in range(n):
        left_diagonal[i + chromosome[i] - 1] += 1
        right_diagonal[len(chromosome) - i + chromosome[i] - 2] += 1

    diagonal_collisions = 0
    for i in range(2*n-1):
        counter = 0
        if left_diagonal[i] > 1:
            counter += left_diagonal[i]-1
        if right_diagonal[i] > 1:
            counter += right_diagonal[i]-1
        diagonal_collisions += counter / (n-abs(i-n+1))

    return int(maxFitness - (horizontal_collisions + diagonal_collisions)) #28-(2+3)=23

def probability(chromosome, fitness):
    return fitness(chromosome) / maxFitness

def random_pick(population, probabilities):
    populationWithProbabilty = zip(population, probabilities)
    total = sum(w for c, w in populationWithProbabilty)
    r = random.uniform(0, total)
    upto = 0
    for c, w in zip(population, probabilities):
        if upto + w >= r:
            return c
        upto += w
    assert False, "Shouldn't get here"

def reproduce(x, y): #doing cross_over between two chromosomes
    n = len(x)
    c = random.randint(0, n - 1)
    return x[0:c] + y[c:n]

def mutate(x):  #randomly changing the value of a random index of a chromosome
    n = len(x)
    c = random.randint(0, n - 1)
    m = random.randint(1, n)
    x[c] = m
    return x

def genetic_queen(population, fitness):
    mutation_probability = 0.03
    new_population = []
    probabilities = [probability(n, fitness) for n in population]
    for i in range(len(population)):
        x = random_pick(population, probabilities) #best chromosome 1
        y = random_pick(population, probabilities) #best chromosome 2
        child = reproduce(x, y) #creating two new chromosomes from the best 2 chromosomes
        if random.random() < mutation_probability:
            child = mutate(child)
        print_chromosome(child)
        new_population.append(child)
        if fitness(child) == maxFitness: break
    return new_population

def print_chromosome(chrom):
    print("Chromosome = {},  Fitness = {}"
        .format(str(chrom), fitness(chrom)))


if __name__ == "__main__":

    nq = int(input("Enter Number of Queens: ")) #say N = 8
    maxFitness = (nq*(nq-1))/2  # 8*7/2 = 28
    population = [random_chromosome(nq) for _ in range(100)]

    generation = 1

    while not maxFitness in [fitness(chrom) for chrom in population]:
        print("=== Generation {} ===".format(generation))
        population = genetic_queen(population, fitness)
        print("")
        print("Maximum Fitness = {}".format(max([fitness(n) for n in population])))
        generation += 1
    chrom_out = []
    print("Solved in Generation {}!".format(generation-1))
    for chrom in population:
        if fitness(chrom) == maxFitness:
            print("");
            print("One of the solutions: ")
            chrom_out = chrom
            print_chromosome(chrom)

    board = []

    for x in range(nq):
        board.append(["x"] * nq)

    for i in range(nq):
        board[nq-chrom_out[i]][i]="Q"


    def print_board(board):
        for row in board:
            print (" ".join(row))

    print()
    print_board(board)
# Out:
# Enter Number of Queens: 4
# === Generation 1 ===
# Chromosome = [1, 4, 4, 2],  Fitness = 4
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [1, 3, 4, 2],  Fitness = 5
# Chromosome = [4, 2, 2, 2],  Fitness = 2
# Chromosome = [4, 4, 1, 3],  Fitness = 5
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [2, 1, 2, 1],  Fitness = 2
# Chromosome = [1, 3, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 1, 4, 1],  Fitness = 3
# Chromosome = [3, 4, 3, 3],  Fitness = 2
# Chromosome = [4, 3, 3, 3],  Fitness = 2
# Chromosome = [1, 2, 3, 3],  Fitness = 4
# Chromosome = [4, 3, 3, 4],  Fitness = 3
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 3, 4, 1],  Fitness = 4
# Chromosome = [2, 3, 3, 4],  Fitness = 4
# Chromosome = [1, 3, 2, 1],  Fitness = 4
# Chromosome = [2, 3, 2, 2],  Fitness = 2
# Chromosome = [3, 2, 2, 2],  Fitness = 2
# Chromosome = [2, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 4, 3, 4],  Fitness = 2
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [2, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 1, 3, 3],  Fitness = 3
# Chromosome = [2, 4, 2, 1],  Fitness = 4
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [4, 2, 4, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 3, 3, 2],  Fitness = 4
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 3, 2, 3],  Fitness = 4
# Chromosome = [1, 3, 3, 2],  Fitness = 4
# Chromosome = [1, 2, 1, 3],  Fitness = 4
# Chromosome = [1, 4, 4, 3],  Fitness = 4
# Chromosome = [4, 1, 1, 1],  Fitness = 2
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 3, 1, 3],  Fitness = 4
# Chromosome = [2, 4, 2, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 3, 3, 1],  Fitness = 2
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 2],  Fitness = 4
# Chromosome = [2, 1, 2, 2],  Fitness = 2
# Chromosome = [1, 4, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [2, 3, 1, 4],  Fitness = 5
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 4, 4, 2],  Fitness = 2
# Chromosome = [1, 3, 2, 3],  Fitness = 4
# Chromosome = [1, 4, 4, 4],  Fitness = 2
# Chromosome = [3, 2, 2, 4],  Fitness = 4
# Chromosome = [3, 3, 2, 3],  Fitness = 2
# Chromosome = [3, 2, 1, 2],  Fitness = 3
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [2, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 4, 4, 4],  Fitness = 2
# Chromosome = [2, 3, 2, 2],  Fitness = 2
# Chromosome = [4, 4, 3, 4],  Fitness = 2
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [1, 4, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 3, 3, 2],  Fitness = 2
# Chromosome = [3, 1, 2, 2],  Fitness = 4
# Chromosome = [2, 2, 2, 2],  Fitness = 0
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 1, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 3],  Fitness = 4
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [3, 3, 2, 4],  Fitness = 4
# Chromosome = [3, 4, 2, 2],  Fitness = 4
# Chromosome = [2, 1, 4, 1],  Fitness = 4
# Chromosome = [2, 3, 2, 2],  Fitness = 2
# Chromosome = [2, 1, 2, 2],  Fitness = 2
# Chromosome = [3, 2, 2, 2],  Fitness = 2
# Chromosome = [2, 4, 3, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [2, 3, 2, 3],  Fitness = 3
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [3, 2, 1, 4],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [4, 3, 3, 2],  Fitness = 4
# Chromosome = [1, 3, 2, 4],  Fitness = 5
# Chromosome = [3, 1, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
#
# Maximum Fitness = 5
# === Generation 2 ===
# Chromosome = [4, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 1, 2, 1],  Fitness = 4
# Chromosome = [2, 2, 4, 2],  Fitness = 2
# Chromosome = [2, 3, 3, 2],  Fitness = 3
# Chromosome = [2, 3, 1, 4],  Fitness = 5
# Chromosome = [1, 2, 2, 3],  Fitness = 4
# Chromosome = [2, 4, 2, 2],  Fitness = 2
# Chromosome = [4, 2, 4, 1],  Fitness = 4
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [3, 4, 3, 3],  Fitness = 2
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 2],  Fitness = 4
# Chromosome = [4, 3, 3, 2],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [1, 3, 2, 3],  Fitness = 4
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [4, 1, 3, 4],  Fitness = 4
# Chromosome = [3, 3, 2, 3],  Fitness = 2
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [2, 1, 3, 2],  Fitness = 4
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [3, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [2, 2, 2, 3],  Fitness = 2
# Chromosome = [2, 4, 4, 1],  Fitness = 4
# Chromosome = [2, 3, 2, 2],  Fitness = 2
# Chromosome = [1, 1, 4, 1],  Fitness = 3
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [4, 4, 4, 2],  Fitness = 2
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 4, 3, 4],  Fitness = 2
# Chromosome = [3, 4, 3, 3],  Fitness = 2
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [1, 3, 2, 2],  Fitness = 4
# Chromosome = [2, 1, 2, 3],  Fitness = 3
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [3, 3, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [2, 2, 3, 3],  Fitness = 3
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [2, 2, 4, 2],  Fitness = 2
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [3, 1, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 2],  Fitness = 2
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [1, 2, 2, 4],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 1, 3, 2],  Fitness = 4
# Chromosome = [3, 4, 3, 4],  Fitness = 2
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 1, 2, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 4, 2, 2],  Fitness = 4
# Chromosome = [2, 4, 2, 2],  Fitness = 2
# Chromosome = [3, 2, 2, 2],  Fitness = 2
# Chromosome = [2, 3, 3, 2],  Fitness = 3
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 3, 4, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 3, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 3],  Fitness = 4
# Chromosome = [3, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [1, 4, 4, 3],  Fitness = 4
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [4, 1, 2, 4],  Fitness = 4
#
# Maximum Fitness = 5
# === Generation 3 ===
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [2, 3, 3, 1],  Fitness = 4
# Chromosome = [3, 2, 2, 2],  Fitness = 2
# Chromosome = [1, 1, 3, 2],  Fitness = 4
# Chromosome = [3, 1, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 1, 1],  Fitness = 2
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [1, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [2, 2, 2, 3],  Fitness = 2
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 2, 3],  Fitness = 3
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 2],  Fitness = 3
# Chromosome = [3, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [2, 2, 1, 1],  Fitness = 3
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [2, 1, 1, 3],  Fitness = 4
# Chromosome = [1, 4, 4, 4],  Fitness = 2
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [1, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [3, 2, 1, 2],  Fitness = 3
# Chromosome = [1, 2, 2, 1],  Fitness = 3
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [2, 1, 4, 1],  Fitness = 4
# Chromosome = [3, 1, 1, 3],  Fitness = 3
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [1, 2, 1, 1],  Fitness = 2
# Chromosome = [3, 4, 2, 1],  Fitness = 5
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [1, 3, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 2],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [1, 1, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [4, 4, 4, 2],  Fitness = 2
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 3, 3, 2],  Fitness = 4
# Chromosome = [2, 4, 4, 4],  Fitness = 2
# Chromosome = [3, 3, 2, 1],  Fitness = 4
# Chromosome = [2, 3, 2, 2],  Fitness = 2
# Chromosome = [2, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 4, 1, 1],  Fitness = 4
# Chromosome = [2, 4, 2, 2],  Fitness = 2
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 2],  Fitness = 4
# Chromosome = [1, 3, 4, 1],  Fitness = 4
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [4, 2, 3, 1],  Fitness = 5
# Chromosome = [1, 1, 1, 3],  Fitness = 2
# Chromosome = [4, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 3, 3, 4],  Fitness = 2
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [1, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 3, 4, 2],  Fitness = 4
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 1, 3, 2],  Fitness = 5
#
# Maximum Fitness = 5
# === Generation 4 ===
# Chromosome = [2, 2, 3, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 1],  Fitness = 4
# Chromosome = [3, 2, 1, 4],  Fitness = 5
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [4, 4, 4, 3],  Fitness = 2
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [2, 2, 3, 2],  Fitness = 2
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 4, 4, 1],  Fitness = 4
# Chromosome = [3, 1, 1, 3],  Fitness = 3
# Chromosome = [3, 2, 4, 4],  Fitness = 4
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 3, 1, 1],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [3, 4, 1, 2],  Fitness = 4
# Chromosome = [4, 3, 2, 4],  Fitness = 4
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [3, 3, 2, 3],  Fitness = 2
# Chromosome = [1, 2, 3, 1],  Fitness = 4
# Chromosome = [4, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 2, 3, 1],  Fitness = 5
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 3, 3, 2],  Fitness = 2
# Chromosome = [2, 4, 1, 2],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [3, 4, 4, 3],  Fitness = 3
# Chromosome = [2, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 4, 1],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 2, 1, 2],  Fitness = 3
# Chromosome = [4, 1, 2, 2],  Fitness = 4
# Chromosome = [4, 2, 2, 2],  Fitness = 2
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [2, 1, 4, 1],  Fitness = 4
# Chromosome = [2, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 2],  Fitness = 2
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 4, 2, 2],  Fitness = 3
# Chromosome = [4, 4, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [1, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [4, 2, 1, 1],  Fitness = 4
# Chromosome = [1, 4, 4, 4],  Fitness = 2
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [4, 1, 3, 2],  Fitness = 5
# Chromosome = [1, 1, 1, 3],  Fitness = 2
# Chromosome = [1, 1, 3, 2],  Fitness = 4
# Chromosome = [2, 2, 1, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [4, 3, 2, 1],  Fitness = 5
# Chromosome = [4, 4, 2, 3],  Fitness = 4
# Chromosome = [2, 3, 1, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [1, 1, 3, 3],  Fitness = 3
# Chromosome = [1, 4, 1, 1],  Fitness = 3
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 1, 2, 1],  Fitness = 4
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [1, 1, 1, 2],  Fitness = 2
# Chromosome = [3, 1, 3, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 4, 3],  Fitness = 4
# Chromosome = [3, 2, 2, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [1, 1, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 3, 2, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [4, 1, 2, 1],  Fitness = 4
#
# Maximum Fitness = 5
# === Generation 5 ===
# Chromosome = [4, 4, 2, 4],  Fitness = 2
# Chromosome = [4, 1, 1, 3],  Fitness = 4
# Chromosome = [2, 2, 3, 2],  Fitness = 2
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [4, 3, 1, 4],  Fitness = 4
# Chromosome = [1, 2, 4, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [2, 4, 1, 1],  Fitness = 5
# Chromosome = [4, 2, 4, 3],  Fitness = 4
# Chromosome = [4, 3, 2, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [2, 2, 4, 4],  Fitness = 3
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [3, 3, 3, 4],  Fitness = 2
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [2, 4, 1, 4],  Fitness = 5
# Chromosome = [3, 1, 2, 1],  Fitness = 4
# Chromosome = [3, 1, 1, 2],  Fitness = 4
# Chromosome = [4, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 2, 3, 1],  Fitness = 5
# Chromosome = [3, 4, 1, 3],  Fitness = 4
# Chromosome = [2, 4, 2, 2],  Fitness = 2
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 4, 2, 2],  Fitness = 4
# Chromosome = [3, 2, 1, 4],  Fitness = 5
# Chromosome = [3, 2, 4, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [2, 4, 4, 2],  Fitness = 3
# Chromosome = [3, 3, 2, 1],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 3, 2, 4],  Fitness = 4
# Chromosome = [3, 1, 3, 3],  Fitness = 2
# Chromosome = [1, 1, 1, 2],  Fitness = 2
# Chromosome = [4, 3, 1, 2],  Fitness = 5
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [3, 1, 1, 3],  Fitness = 3
# Chromosome = [3, 2, 4, 4],  Fitness = 4
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 1, 2, 2],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [1, 2, 1, 2],  Fitness = 2
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 4, 3, 4],  Fitness = 2
# Chromosome = [1, 4, 4, 1],  Fitness = 4
# Chromosome = [1, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [1, 4, 1, 4],  Fitness = 3
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [4, 4, 1, 1],  Fitness = 3
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [1, 1, 2, 4],  Fitness = 4
# Chromosome = [3, 2, 4, 1],  Fitness = 5
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [2, 2, 3, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 2, 1, 1],  Fitness = 4
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [3, 3, 2, 2],  Fitness = 3
# Chromosome = [3, 3, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [3, 2, 4, 2],  Fitness = 4
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [4, 4, 2, 2],  Fitness = 3
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 3],  Fitness = 5
# Chromosome = [3, 1, 2, 4],  Fitness = 5
# Chromosome = [3, 1, 2, 3],  Fitness = 4
# Chromosome = [4, 1, 2, 1],  Fitness = 4
# Chromosome = [4, 2, 3, 3],  Fitness = 4
# Chromosome = [4, 2, 2, 3],  Fitness = 4
# Chromosome = [3, 4, 1, 2],  Fitness = 4
# Chromosome = [2, 1, 2, 3],  Fitness = 3
# Chromosome = [1, 1, 3, 4],  Fitness = 4
# Chromosome = [2, 2, 3, 2],  Fitness = 2
# Chromosome = [4, 2, 4, 4],  Fitness = 2
# Chromosome = [3, 4, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 3],  Fitness = 5
# Chromosome = [1, 4, 1, 1],  Fitness = 3
#
# Maximum Fitness = 5
# === Generation 6 ===
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [2, 4, 1, 1],  Fitness = 5
# Chromosome = [1, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [1, 2, 3, 4],  Fitness = 5
# Chromosome = [3, 4, 1, 1],  Fitness = 4
# Chromosome = [3, 2, 4, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 1],  Fitness = 4
# Chromosome = [3, 4, 2, 3],  Fitness = 4
# Chromosome = [3, 2, 1, 3],  Fitness = 4
# Chromosome = [1, 1, 2, 4],  Fitness = 4
# Chromosome = [4, 1, 2, 2],  Fitness = 4
# Chromosome = [4, 2, 1, 4],  Fitness = 4
# Chromosome = [4, 2, 1, 2],  Fitness = 4
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 2, 3, 2],  Fitness = 3
# Chromosome = [3, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 1, 3, 3],  Fitness = 2
# Chromosome = [3, 2, 1, 4],  Fitness = 5
# Chromosome = [2, 1, 1, 2],  Fitness = 3
# Chromosome = [4, 1, 4, 4],  Fitness = 3
# Chromosome = [4, 2, 3, 4],  Fitness = 4
# Chromosome = [3, 4, 1, 4],  Fitness = 4
# Chromosome = [3, 4, 4, 4],  Fitness = 2
# Chromosome = [4, 2, 4, 2],  Fitness = 4
# Chromosome = [4, 1, 2, 4],  Fitness = 4
# Chromosome = [2, 2, 1, 4],  Fitness = 4
# Chromosome = [2, 4, 2, 4],  Fitness = 4
# Chromosome = [4, 2, 2, 4],  Fitness = 3
# Chromosome = [2, 4, 1, 3],  Fitness = 6
#
# Maximum Fitness = 6
# Solved in Generation 6!
#
# One of the solutions:
# Chromosome = [2, 4, 1, 3],  Fitness = 6
#
# x Q x x
# x x x Q
# Q x x x
# x x Q x

# %%
# Python3 program to implement traveling salesman
# problem using naive approach.
from sys import maxsize
from itertools import permutations
V = 4

# implementation of traveling Salesman Problem
def travellingSalesmanProblem(graph, s):

	# store all vertex apart from source vertex
	vertex = []
	for i in range(V):
		if i != s:
			vertex.append(i)

	# store minimum weight Hamiltonian Cycle
	min_path = maxsize
	next_permutation=permutations(vertex)
	for i in next_permutation:

		# store current Path weight(cost)
		current_pathweight = 0

		# compute current path weight
		k = s
		for j in i:
			current_pathweight += graph[k][j]
			k = j
		current_pathweight += graph[k][s]

		# update minimum
		min_path = min(min_path, current_pathweight)

	return min_path


# Driver Code
if __name__ == "__main__":

	# matrix representation of graph
	graph = [[0, 20, 15, 30], [10, 0, 45, 25],
			[15, 25, 0, 30], [30, 25, 10, 0]]
	s = 0
	print(travellingSalesmanProblem(graph, s))
# Out:
# 70
